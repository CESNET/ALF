# %%
import sklearn.datasets
from sklearn.decomposition import PCA
import seaborn as sns

# %%
data,target = sklearn.datasets.load_iris(as_frame=True,return_X_y=True)

# %%
# pca for visualization
pca = PCA(n_components=2)
data_pca = pca.fit_transform(data)

# %%
sns.scatterplot(x=data_pca[:,0], y=data_pca[:,1], hue=target)
# Out:
# <AxesSubplot: >

# %%
from alf.al_module.query_strategies.anomaly_based import IsolationForest

# %%
iforest = IsolationForest(None, None)

# %%
iforest.select(data)
# Out:
# 5
